# %%
from selenium import webdriver 
import requests
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
import pandas as pd
import time
from collections import ChainMap

# %%
driver = webdriver.Chrome()
driver.get('https://tweedekamer2021.stemwijzer.nl/#/')
driver.find_element(by=By.CSS_SELECTOR, value='body > div > div > div > div.start__modal-left > div.start__modal > div.start__modal-footer > button').click()
#driver.find_element_by_css_selector('body > div > div > div.statement__inner > div > button.statement__tab-button.statement__tab-button--parties').click()
votes_per_party = []
error_count = 0
'''

'''
for i in range(30):
    try:
        time.sleep(1)
        question = driver.find_element(by = By.CSS_SELECTOR, value = 'body > div > div > div.statement__inner > h1').text #select the statement element
        time.sleep(1)
        driver.find_element(by = By.CSS_SELECTOR, value = 'body > div > div > div.statement__inner > div > button.statement__tab-button.statement__tab-button--parties').click()#open the tab that contains the opinion of the parties
        time.sleep(1)
        agrees = driver.find_element(by = By.CSS_SELECTOR, value = 'body > div > div > div.statement__tab.statement__tab--parties > div:nth-child(1)').text.split('\n')[2:] #all parties that agree with the statement
        time.sleep(1)
        neutral =  driver.find_element(by = By.CSS_SELECTOR, value = 'body > div > div > div.statement__tab.statement__tab--parties > div:nth-child(2)').text.split('\n')[2:]#all parties that are neutral on the statement
        time.sleep(1)
        disagrees =  driver.find_element(by = By.CSS_SELECTOR, value = 'body > div > div > div.statement__tab.statement__tab--parties > div:nth-child(3)').text.split('\n')[2:]#all parties that disagree with the statement
        time.sleep(1)
        agrees_dict = {party : 1 for party in agrees}#score of 1 if the party agrees with the statement
        disagrees_dict = {party : -1 for party in disagrees}#score of 0 if the party agrees with the statement
        neutral_dict = {party : 0 for party in neutral}#score of -1 if the party agrees with the statement
        question_dict = {'question': question}
        full_dict = dict(question_dict, **agrees_dict, **disagrees_dict , **neutral_dict)    
        if len(votes_per_party) > 0: #otherwise and index-error occurs.
            if votes_per_party[len(votes_per_party) - 1]['question'] == question:#compare the block to previous statement. Sometimes, the scraper fails to go to the next page. this avoids saving duplicate questions
                print('failed to go to next page')
                raise ValueError
        votes_per_party.append(full_dict)
        error_count = 0#
        try:
            driver.find_element(by = By.CSS_SELECTOR, value ='body > div > div > div.statement__buttons > div.statement__buttons-mobile > div > div:nth-child(2) > button').click()
        except:
            driver.find_element(by = By.CSS_SELECTOR, value = 'body > div > div > div.statement__buttons.statement__buttons--floating > div.statement__buttons-mobile > div > div:nth-child(2) > button').click()
        time.sleep(1)
        if len(votes_per_party) == 30:
            break
    except Exception as e: 
        print(e)
        error_count +=1
        if error_count > 10:
            break
# Out:
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"body > div > div > div.statement__inner > h1"}
#   (Session info: chrome=100.0.4896.60)
# Stacktrace:
# 0   chromedriver                        0x000000010500b370 chromedriver + 4420464
# 1   chromedriver                        0x0000000104fa2940 chromedriver + 3991872
# 2   chromedriver                        0x0000000104c02548 chromedriver + 189768
# 3   chromedriver                        0x0000000104c30ef8 chromedriver + 380664
# 4   chromedriver                        0x0000000104c59bfc chromedriver + 547836
# 5   chromedriver                        0x0000000104c26248 chromedriver + 336456
# 6   chromedriver                        0x0000000104fcf548 chromedriver + 4175176
# 7   chromedriver                        0x0000000104fe595c chromedriver + 4266332
# 8   chromedriver                        0x0000000104fea660 chromedriver + 4286048
# 9   chromedriver                        0x0000000104fe6124 chromedriver + 4268324
# 10  chromedriver                        0x0000000104fc553c chromedriver + 4134204
# 11  chromedriver                        0x0000000104ffdeb0 chromedriver + 4366000
# 12  chromedriver                        0x0000000104ffe014 chromedriver + 4366356
# 13  chromedriver                        0x0000000105011a6c chromedriver + 4446828
# 14  libsystem_pthread.dylib             0x00000001be089240 _pthread_start + 148
# 15  libsystem_pthread.dylib             0x00000001be084024 thread_start + 8
#
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"body > div > div > div.statement__inner > h1"}
#   (Session info: chrome=100.0.4896.60)
# Stacktrace:
# 0   chromedriver                        0x000000010500b370 chromedriver + 4420464
# 1   chromedriver                        0x0000000104fa2940 chromedriver + 3991872
# 2   chromedriver                        0x0000000104c02548 chromedriver + 189768
# 3   chromedriver                        0x0000000104c30ef8 chromedriver + 380664
# 4   chromedriver                        0x0000000104c59bfc chromedriver + 547836
# 5   chromedriver                        0x0000000104c26248 chromedriver + 336456
# 6   chromedriver                        0x0000000104fcf548 chromedriver + 4175176
# 7   chromedriver                        0x0000000104fe595c chromedriver + 4266332
# 8   chromedriver                        0x0000000104fea660 chromedriver + 4286048
# 9   chromedriver                        0x0000000104fe6124 chromedriver + 4268324
# 10  chromedriver                        0x0000000104fc553c chromedriver + 4134204
# 11  chromedriver                        0x0000000104ffdeb0 chromedriver + 4366000
# 12  chromedriver                        0x0000000104ffe014 chromedriver + 4366356
# 13  chromedriver                        0x0000000105011a6c chromedriver + 4446828
# 14  libsystem_pthread.dylib             0x00000001be089240 _pthread_start + 148
# 15  libsystem_pthread.dylib             0x00000001be084024 thread_start + 8

# %%
psdfvotes_per_party

# %%
votes_per_party[29]
# Out:
# {'question': 'Mensen moeten altijd zelf kunnen kiezen of ze een mondkapje dragen.',
#  'Partij voor de Dieren': 1,
#  'SGP': 1,
#  'DENK': 1,
#  'Forum voor Democratie': 1,
#  'Code Oranje': 1,
#  'NIDA': 1,
#  'Piratenpartij': 1,
#  'Libertaire Partij': 1,
#  'Splinter': 1,
#  'BoerBurgerBeweging': 1,
#  'Lijst Henk Krol': 1,
#  'Oprecht': 1,
#  'Jezus Leeft': 1,
#  'Trots op Nederland': 1,
#  'Lijst30': 1,
#  'VVD': -1,
#  'PVV': -1,
#  'CDA': -1,
#  'D66': -1,
#  'GroenLinks': -1,
#  'SP': -1,
#  'Partij van de Arbeid': -1,
#  'ChristenUnie': -1,
#  '50PLUS': -1,
#  'BIJ1': -1,
#  'Volt': -1,
#  'JONG': -1,
#  'NLBeter': -1,
#  'U-Buntu Connected Front': -1,
#  'JA21': 0}

# %%
pdf_votes_per_party_stemwijzer_2021 = pd.DataFrame(votes_per_party)

# %%
for col in pdf_votes_per_party_stemwijzer_2021.columns:
    if col != 'question':
        pdf_votes_per_party_stemwijzer_2021[f'volt_difference_{col}'] = abs(pdf_votes_per_party_stemwijzer_2021[col] - pdf_votes_per_party_stemwijzer_2021['Volt'])

# %%
volt_difference_sum = [{col + '_sum': sum(pdf_votes_per_party_stemwijzer_2021[col])} 
 for col in pdf_votes_per_party_stemwijzer_2021.columns if 'difference' in col]
volt_difference_sum = [dict(ChainMap(*volt_difference_sum))]

# %%
pdf_votes_per_party_stemwijzer_2021.to_csv('stemwijzer_2021_stemgedrag_per_partij.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 pdf_votes_per_party_stemwijzer_2021.to_csv('stemwijzer_2021_stemgedrag_per_partij.csv')
#
# NameError: name 'pdf_votes_per_party_stemwijzer_2021' is not defined

# %%
pdf_volt_difference_landelijk = pd.DataFrame(volt_difference_sum)

# %%
pdf_volt_difference_landelijk.to_csv('sum_difference_national_electorate_with_volt_stemwijzer.csv')

# %%
print(1)
# Out:
# 1

# %%
driver = webdriver.Chrome()
driver.get('https://denhaag.stemwijzer.nl/')
driver.find_element(by=By.CSS_SELECTOR, value='body > div > div > div > div.start__modal-left > div.start__modal > div.start__modal-footer > button').click()

votes_per_party_2022 = []

# %%
error_count = 0

while True:
    print('test')
    try:
        print('start')
        time.sleep(1)
        question = driver.find_element(by = By.CSS_SELECTOR, value = 'body > div > div > div.statement__inner > h1').text
        print(question)
        time.sleep(1)
        driver.find_element(by = By.CSS_SELECTOR, value = 'body > div > div > div.statement__inner > div > button').click()#check
        time.sleep(1)
        agrees = driver.find_element(by = By.CSS_SELECTOR, value =  'body > div > div > div.statement__tab.statement__tab--parties > div:nth-child(1)').text.split('\n')[2:]
        print(len(agrees))
        time.sleep(1)
        neutral =  driver.find_element(by = By.CSS_SELECTOR, value = 'body > div > div > div.statement__tab.statement__tab--parties > div:nth-child(2)').text.split('\n')[2:]
        print(len(neutral))
        time.sleep(1)
        disagrees =  driver.find_element(by = By.CSS_SELECTOR, value = 'body > div > div > div.statement__tab.statement__tab--parties > div:nth-child(3)').text.split('\n')[2:]
        print(len(disagrees))
        time.sleep(1)
        
        agrees_dict = {party : 1 for party in agrees}
        disagrees_dict = {party : -1 for party in disagrees}
        neutral_dict = {party : 0 for party in neutral}
        question_dict = {'question': question}
        full_dict = dict(question_dict, **agrees_dict, **disagrees_dict , **neutral_dict)    
        #driver.find_element(by=By.CLASS_NAME, value='statement__skip statement__skip--mobile skip').click()
        if len(votes_per_party_2022) > 0:
            if votes_per_party_2022[len(votes_per_party_2022) - 1]['question'] == question:
                raise ValueError
        votes_per_party_2022.append(full_dict)
        error_count = 0
        try:
            time.sleep(1)
            print('poging 1')
            driver.find_element(by = By.CSS_SELECTOR, value = 'body > div > div > div.statement__buttons.statement__buttons--floating > div.statement__buttons-mobile > div > div:nth-child(2) > button').click()
        except:
            time.sleep(1)
            print('poging 2')
            try:
                driver.find_element(by = By.CSS_SELECTOR, value = 'body > div > div > div.statement__buttons.statement__buttons--floating > div.statement__buttons-mobile > div > div:nth-child(1) > button').click()
            except:
                print('poging 3')
                time.sleep(1)
                driver.find_element(by = By.CSS_SELECTOR, value = 'body > div > div > div.statement__buttons.statement__buttons--floating > div.statement__buttons-main > button.statement__button.button.button--neither').click()
        time.sleep(1)
        if len(votes_per_party_2022) == 30:
            break
        
    except Exception as e: 
        print(e)
        error_count +=1
        print(f'error count: {error_count}')
        if error_count > 10:
            break
# Out:
# test
# start
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"body > div > div > div.statement__inner > h1"}
#   (Session info: chrome=100.0.4896.60)
# Stacktrace:
# 0   chromedriver                        0x00000001047d7370 chromedriver + 4420464
# 1   chromedriver                        0x000000010476e940 chromedriver + 3991872
# 2   chromedriver                        0x00000001043ce548 chromedriver + 189768
# 3   chromedriver                        0x00000001043fcef8 chromedriver + 380664
# 4   chromedriver                        0x0000000104425bfc chromedriver + 547836
# 5   chromedriver                        0x00000001043f2248 chromedriver + 336456
# 6   chromedriver                        0x000000010479b548 chromedriver + 4175176
# 7   chromedriver                        0x00000001047b195c chromedriver + 4266332
# 8   chromedriver                        0x00000001047b6660 chromedriver + 4286048
# 9   chromedriver                        0x00000001047b2124 chromedriver + 4268324
# 10  chromedriver                        0x000000010479153c chromedriver + 4134204
# 11  chromedriver                        0x00000001047c9eb0 chromedriver + 4366000
# 12  chromedriver                        0x00000001047ca014 chromedriver + 4366356
# 13  chromedriver                        0x00000001047dda6c chromedriver + 4446828
# 14  libsystem_pthread.dylib             0x00000001be089240 _pthread_start + 148
# 15  libsystem_pthread.dylib             0x00000001be084024 thread_start + 8
#
# error count: 1
# test
# start
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"body > div > div > div.statement__inner > h1"}
#   (Session info: chrome=100.0.4896.60)
# Stacktrace:
# 0   chromedriver                        0x00000001047d7370 chromedriver + 4420464
# 1   chromedriver                        0x000000010476e940 chromedriver + 3991872
# 2   chromedriver                        0x00000001043ce548 chromedriver + 189768
# 3   chromedriver                        0x00000001043fcef8 chromedriver + 380664
# 4   chromedriver                        0x0000000104425bfc chromedriver + 547836
# 5   chromedriver                        0x00000001043f2248 chromedriver + 336456
# 6   chromedriver                        0x000000010479b548 chromedriver + 4175176
# 7   chromedriver                        0x00000001047b195c chromedriver + 4266332
# 8   chromedriver                        0x00000001047b6660 chromedriver + 4286048
# 9   chromedriver                        0x00000001047b2124 chromedriver + 4268324
# 10  chromedriver                        0x000000010479153c chromedriver + 4134204
# 11  chromedriver                        0x00000001047c9eb0 chromedriver + 4366000
# 12  chromedriver                        0x00000001047ca014 chromedriver + 4366356
# 13  chromedriver                        0x00000001047dda6c chromedriver + 4446828
# 14  libsystem_pthread.dylib             0x00000001be089240 _pthread_start + 148
# 15  libsystem_pthread.dylib             0x00000001be084024 thread_start + 8
#
# error count: 2
# test
# start
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"body > div > div > div.statement__inner > h1"}
#   (Session info: chrome=100.0.4896.60)
# Stacktrace:
# 0   chromedriver                        0x00000001047d7370 chromedriver + 4420464
# 1   chromedriver                        0x000000010476e940 chromedriver + 3991872
# 2   chromedriver                        0x00000001043ce548 chromedriver + 189768
# 3   chromedriver                        0x00000001043fcef8 chromedriver + 380664
# 4   chromedriver                        0x0000000104425bfc chromedriver + 547836
# 5   chromedriver                        0x00000001043f2248 chromedriver + 336456
# 6   chromedriver                        0x000000010479b548 chromedriver + 4175176
# 7   chromedriver                        0x00000001047b195c chromedriver + 4266332
# 8   chromedriver                        0x00000001047b6660 chromedriver + 4286048
# 9   chromedriver                        0x00000001047b2124 chromedriver + 4268324
# 10  chromedriver                        0x000000010479153c chromedriver + 4134204
# 11  chromedriver                        0x00000001047c9eb0 chromedriver + 4366000
# 12  chromedriver                        0x00000001047ca014 chromedriver + 4366356
# 13  chromedriver                        0x00000001047dda6c chromedriver + 4446828
# 14  libsystem_pthread.dylib             0x00000001be089240 _pthread_start + 148
# 15  libsystem_pthread.dylib             0x00000001be084024 thread_start + 8
#
# error count: 3
# test
# start
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"body > div > div > div.statement__inner > h1"}
#   (Session info: chrome=100.0.4896.60)
# Stacktrace:
# 0   chromedriver                        0x00000001047d7370 chromedriver + 4420464
# 1   chromedriver                        0x000000010476e940 chromedriver + 3991872
# 2   chromedriver                        0x00000001043ce548 chromedriver + 189768
# 3   chromedriver                        0x00000001043fcef8 chromedriver + 380664
# 4   chromedriver                        0x0000000104425bfc chromedriver + 547836
# 5   chromedriver                        0x00000001043f2248 chromedriver + 336456
# 6   chromedriver                        0x000000010479b548 chromedriver + 4175176
# 7   chromedriver                        0x00000001047b195c chromedriver + 4266332
# 8   chromedriver                        0x00000001047b6660 chromedriver + 4286048
# 9   chromedriver                        0x00000001047b2124 chromedriver + 4268324
# 10  chromedriver                        0x000000010479153c chromedriver + 4134204
# 11  chromedriver                        0x00000001047c9eb0 chromedriver + 4366000
# 12  chromedriver                        0x00000001047ca014 chromedriver + 4366356
# 13  chromedriver                        0x00000001047dda6c chromedriver + 4446828
# 14  libsystem_pthread.dylib             0x00000001be089240 _pthread_start + 148
# 15  libsystem_pthread.dylib             0x00000001be084024 thread_start + 8
#
# error count: 4
# test
# start
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"body > div > div > div.statement__inner > h1"}
#   (Session info: chrome=100.0.4896.60)
# Stacktrace:
# 0   chromedriver                        0x00000001047d7370 chromedriver + 4420464
# 1   chromedriver                        0x000000010476e940 chromedriver + 3991872
# 2   chromedriver                        0x00000001043ce548 chromedriver + 189768
# 3   chromedriver                        0x00000001043fcef8 chromedriver + 380664
# 4   chromedriver                        0x0000000104425bfc chromedriver + 547836
# 5   chromedriver                        0x00000001043f2248 chromedriver + 336456
# 6   chromedriver                        0x000000010479b548 chromedriver + 4175176
# 7   chromedriver                        0x00000001047b195c chromedriver + 4266332
# 8   chromedriver                        0x00000001047b6660 chromedriver + 4286048
# 9   chromedriver                        0x00000001047b2124 chromedriver + 4268324
# 10  chromedriver                        0x000000010479153c chromedriver + 4134204
# 11  chromedriver                        0x00000001047c9eb0 chromedriver + 4366000
# 12  chromedriver                        0x00000001047ca014 chromedriver + 4366356
# 13  chromedriver                        0x00000001047dda6c chromedriver + 4446828
# 14  libsystem_pthread.dylib             0x00000001be089240 _pthread_start + 148
# 15  libsystem_pthread.dylib             0x00000001be084024 thread_start + 8
#
# error count: 5
# test
# start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [21], in <cell line: 4>()
#       5 try:
#       6     print('start')
# ----> 7     time.sleep(1)
#       8     question = driver.find_element(by = By.CSS_SELECTOR, value = 'body > div > div > div.statement__inner > h1').text
#       9     print(question)
#
# KeyboardInterrupt:

# %%
pdf_votes_per_party_stemwijzer_2022 = pd.DataFrame(votes_per_party_2022)

# %%
pdf_votes_per_party_stemwijzer_2022.to_csv('../data/election_results_2022_the_hague.csv')
